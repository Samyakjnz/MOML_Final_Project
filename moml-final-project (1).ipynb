# %%
# CELL 1: Imports and Data Prep
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, roc_auc_score, confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
import optuna
import matplotlib.pyplot as plt

# Load the dataset
# Ensure 'compas_data.csv' is in your Kaggle input directory
df = pd.read_csv('/kaggle/input/datasets/samyak07060504/dataset/compas_data.csv')

# Define target and protected attribute
TARGET = 'Two_yr_Recidivism'
PROTECTED_ATTR = 'African_American'

# Separate features and target
X = df.drop(columns=[TARGET])
y = df[TARGET]

# Split the data (70% train, 30% validation for the MOO loop)
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

print(f"Training set shape: {X_train.shape}")
print(f"Validation set shape: {X_val.shape}")
# Out:
# Training set shape: (4320, 11)
# Validation set shape: (1852, 11)

# %%
# CELL 2: Evaluation Metrics
def calculate_metrics(y_true, y_pred, y_prob, protected_groups):
    """Calculates the 3 required objectives."""
    
    # 1. Predictive Performance: AUC-ROC
    auc = roc_auc_score(y_true, y_prob)
    
    # Masks for protected groups
    mask_A = (protected_groups == 1) # African American
    mask_B = (protected_groups == 0) # Other
    
    # 2. Demographic Parity
    # 1 - | P(Y_hat=1 | G=A) - P(Y_hat=1 | G=B) |
    pos_rate_A = y_pred[mask_A].mean() if sum(mask_A) > 0 else 0
    pos_rate_B = y_pred[mask_B].mean() if sum(mask_B) > 0 else 0
    demographic_parity = 1.0 - abs(pos_rate_A - pos_rate_B)
    
    # 3. Equalized Odds
    # 1 - max(|TPR_A - TPR_B|, |FPR_A - FPR_B|)
    def get_tpr_fpr(y_t, y_p):
        tn, fp, fn, tp = confusion_matrix(y_t, y_p, labels=[0,1]).ravel()
        tpr = tp / (tp + fn) if (tp + fn) > 0 else 0
        fpr = fp / (fp + tn) if (fp + tn) > 0 else 0
        return tpr, fpr

    tpr_A, fpr_A = get_tpr_fpr(y_true[mask_A], y_pred[mask_A])
    tpr_B, fpr_B = get_tpr_fpr(y_true[mask_B], y_pred[mask_B])
    
    equalized_odds = 1.0 - max(abs(tpr_A - tpr_B), abs(fpr_A - fpr_B))
    
    return auc, demographic_parity, equalized_odds

# %%
# CELL 3: Optuna Trial Definition (UPDATED WITH CLASS IMBALANCE)
def objective(trial):
    # Decision Variable 1: Model Type
    model_type = trial.suggest_categorical("model_type", ["LogisticRegression", "RandomForest", "XGBoost"])
    
    if model_type == "LogisticRegression":
        # Decision Variable 2: Regularization Strength
        C = trial.suggest_float("C", 1e-4, 10.0, log=True)
        # Decision Variable 3: Class Imbalance Handling
        class_weight = trial.suggest_categorical("lr_class_weight", [None, "balanced"])
        
        model = LogisticRegression(C=C, class_weight=class_weight, max_iter=1000, random_state=42)
        
    elif model_type == "RandomForest":
        # Decision Variable 2: Number of Trees
        n_estimators = trial.suggest_int("n_estimators", 50, 300)
        # Decision Variable 3: Tree Depth
        max_depth = trial.suggest_int("max_depth", 3, 15)
        # Decision Variable 4: Class Imbalance Handling
        class_weight = trial.suggest_categorical("rf_class_weight", [None, "balanced", "balanced_subsample"])
        
        model = RandomForestClassifier(n_estimators=n_estimators, max_depth=max_depth, class_weight=class_weight, random_state=42)
        
    elif model_type == "XGBoost":
        # Decision Variable 2: Number of Trees
        n_estimators = trial.suggest_int("xgb_n_estimators", 50, 300)
        # Decision Variable 3: Tree Depth
        max_depth = trial.suggest_int("xgb_max_depth", 3, 10)
        # Decision Variable 4: Learning Rate
        learning_rate = trial.suggest_float("learning_rate", 1e-3, 0.3, log=True)
        # Decision Variable 5: Class Imbalance Handling (scale_pos_weight)
        # 1.0 means no balancing, >1.0 gives more weight to the positive class
        scale_pos_weight = trial.suggest_float("scale_pos_weight", 1.0, 3.0)
        
        model = XGBClassifier(n_estimators=n_estimators, max_depth=max_depth, learning_rate=learning_rate, 
                              scale_pos_weight=scale_pos_weight, random_state=42, use_label_encoder=False, eval_metric='logloss')

    # Train the model
    model.fit(X_train, y_train)
    
    # Predict on validation set
    y_pred = model.predict(X_val)
    y_prob = model.predict_proba(X_val)[:, 1]
    
    # Get protected attributes for validation set
    protected_val = X_val[PROTECTED_ATTR]
    
    # Calculate objectives
    auc, dp, eo = calculate_metrics(y_val, y_pred, y_prob, protected_val)
    
    return auc, dp, eo

# %%
# CELL 4: Execution of the MOO Loop
# We want to MAXIMIZE all three objectives
study = optuna.create_study(
    directions=["maximize", "maximize", "maximize"],
    sampler=optuna.samplers.NSGAIISampler(seed=42)
)

# NOTE: Set n_trials to 20-50 for initial debugging. 
# For your final run, increase to 200-500 depending on Kaggle's processing speed 
# to ensure you extract a dense Pareto front within the 2-hour limit.
print("Starting Multi-Objective Optimization...")
study.optimize(objective, n_trials=100, timeout=7000) # Timeout is slightly under 2 hours
print("Optimization finished!")
# Out:
# [I 2026-04-26 05:51:06,201] A new study created in memory with name: no-name-52b6056e-4b96-43d7-be31-c1a2358d6d6c
# Starting Multi-Objective Optimization...
# [I 2026-04-26 05:51:06,984] Trial 0 finished with values: [0.7379004146548207, 0.6765027271368799, 0.7108728455897957] and parameters: {'model_type': 'RandomForest', 'n_estimators': 200, 'max_depth': 5, 'rf_class_weight': 'balanced_subsample'}.
# [I 2026-04-26 05:51:08,136] Trial 1 finished with values: [0.7059900986024945, 0.75362839958159, 0.7847770730672199] and parameters: {'model_type': 'RandomForest', 'n_estimators': 293, 'max_depth': 13, 'rf_class_weight': None}.
# [I 2026-04-26 05:51:08,693] Trial 2 finished with values: [0.719323243830437, 0.7468759339509863, 0.7843526748874166] and parameters: {'model_type': 'RandomForest', 'n_estimators': 123, 'max_depth': 10, 'rf_class_weight': 'balanced_subsample'}.
# [I 2026-04-26 05:51:09,302] Trial 3 finished with values: [0.7203672287490874, 0.7448539300657502, 0.7834508287553346] and parameters: {'model_type': 'RandomForest', 'n_estimators': 179, 'max_depth': 10, 'rf_class_weight': 'balanced'}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:51:09] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:51:09,549] Trial 4 finished with values: [0.7302874367936495, 1.0, 1.0] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 252, 'xgb_max_depth': 5, 'learning_rate': 0.0017456037635797405, 'scale_pos_weight': 2.3684660530243136}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:51:09] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:51:09,655] Trial 5 finished with values: [0.7157680519453036, 1.0, 1.0] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 58, 'xgb_max_depth': 10, 'learning_rate': 0.004375517173207359, 'scale_pos_weight': 2.325044568707964}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:51:09] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:51:09,794] Trial 6 finished with values: [0.7077923833775968, 0.8550601464435147, 0.8682723723005817] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 96, 'xgb_max_depth': 10, 'learning_rate': 0.08319514671870787, 'scale_pos_weight': 2.8789978831283785}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:51:09] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:51:09,855] Trial 7 finished with values: [0.7290059688191801, 1.0, 1.0] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 72, 'xgb_max_depth': 4, 'learning_rate': 0.001294295611551122, 'scale_pos_weight': 1.6506606615265287}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:51:09] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:51:09,966] Trial 8 finished with values: [0.7343281757186507, 0.746245517035266, 0.7712493810859877] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 139, 'xgb_max_depth': 5, 'learning_rate': 0.022096526145513846, 'scale_pos_weight': 1.2818484499495253}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:51:09] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:51:10,108] Trial 9 finished with values: [0.7321755446532807, 1.0, 1.0] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 243, 'xgb_max_depth': 4, 'learning_rate': 0.0010319982330247674, 'scale_pos_weight': 2.6309228569096685}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:51:10] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:51:10,172] Trial 10 finished with values: [0.7296055547521888, 1.0, 1.0] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 68, 'xgb_max_depth': 5, 'learning_rate': 0.0019365187669093031, 'scale_pos_weight': 2.7262068517511873}.
# [I 2026-04-26 05:51:10,220] Trial 11 finished with values: [0.7417124879641941, 0.6857721906754333, 0.6796972626317402] and parameters: {'model_type': 'LogisticRegression', 'C': 0.0035884889113862576, 'lr_class_weight': 'balanced'}.
# [I 2026-04-26 05:51:10,654] Trial 12 finished with values: [0.7059853959677258, 0.757130715780036, 0.8001615070850918] and parameters: {'model_type': 'RandomForest', 'n_estimators': 80, 'max_depth': 12, 'rf_class_weight': 'balanced_subsample'}.
# [I 2026-04-26 05:51:10,799] Trial 13 finished with values: [0.7359482333964662, 0.6722532501494322, 0.7095289180204183] and parameters: {'model_type': 'RandomForest', 'n_estimators': 56, 'max_depth': 4, 'rf_class_weight': 'balanced'}.
# [I 2026-04-26 05:51:11,537] Trial 14 finished with values: [0.7072645126248109, 0.7505743798565451, 0.7911253625067786] and parameters: {'model_type': 'RandomForest', 'n_estimators': 153, 'max_depth': 12, 'rf_class_weight': 'balanced_subsample'}.
# [I 2026-04-26 05:51:12,595] Trial 15 finished with values: [0.7014044418736707, 0.7500840555887627, 0.7927757998726805] and parameters: {'model_type': 'RandomForest', 'n_estimators': 208, 'max_depth': 14, 'rf_class_weight': 'balanced_subsample'}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:51:12] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:51:12,675] Trial 16 finished with values: [0.7284310717187072, 0.9035929094441123, 0.8702366722448004] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 129, 'xgb_max_depth': 3, 'learning_rate': 0.0036696364068833334, 'scale_pos_weight': 1.8542155772525126}.
# [I 2026-04-26 05:51:13,430] Trial 17 finished with values: [0.7345333281604352, 0.7476371040047818, 0.7780220687053498] and parameters: {'model_type': 'RandomForest', 'n_estimators': 178, 'max_depth': 8, 'rf_class_weight': 'balanced_subsample'}.
# [I 2026-04-26 05:51:13,468] Trial 18 finished with values: [0.7381008644618363, 0.711241034070532, 0.7361775870605711] and parameters: {'model_type': 'LogisticRegression', 'C': 0.3274121520988885, 'lr_class_weight': 'balanced'}.
# [I 2026-04-26 05:51:13,493] Trial 19 finished with values: [0.7412774942480899, 0.7084111625821876, 0.6645839718954094] and parameters: {'model_type': 'LogisticRegression', 'C': 0.0031944165636003663, 'lr_class_weight': None}.
# [I 2026-04-26 05:51:13,517] Trial 20 finished with values: [0.7408542571189073, 0.7029008517632994, 0.6645839718954094] and parameters: {'model_type': 'LogisticRegression', 'C': 0.002473046721099914, 'lr_class_weight': None}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:51:13] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:51:13,720] Trial 21 finished with values: [0.7166309854253592, 0.8119676479378362, 0.848831726121708] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 110, 'xgb_max_depth': 8, 'learning_rate': 0.07702365744928269, 'scale_pos_weight': 1.4752750879847993}.
# [I 2026-04-26 05:51:13,759] Trial 22 finished with values: [0.7381972684745945, 0.7113624476987448, 0.7107019074340415] and parameters: {'model_type': 'LogisticRegression', 'C': 0.1471121537912197, 'lr_class_weight': None}.
# [I 2026-04-26 05:51:13,780] Trial 23 finished with values: [0.7127089880282675, 0.7651159967124925, 0.7487503831372457] and parameters: {'model_type': 'LogisticRegression', 'C': 0.00015991003111214837, 'lr_class_weight': 'balanced'}.
# [I 2026-04-26 05:51:14,594] Trial 24 finished with values: [0.7382578148972415, 0.6787348699940228, 0.7168969419753377] and parameters: {'model_type': 'RandomForest', 'n_estimators': 211, 'max_depth': 5, 'rf_class_weight': 'balanced_subsample'}.
# [I 2026-04-26 05:51:15,997] Trial 25 finished with values: [0.7017906457540498, 0.7327172369994022, 0.7769669676750053] and parameters: {'model_type': 'RandomForest', 'n_estimators': 282, 'max_depth': 14, 'rf_class_weight': 'balanced_subsample'}.
# [I 2026-04-26 05:51:16,017] Trial 26 finished with values: [0.7186390104715921, 0.7643501569037656, 0.7499587390658524] and parameters: {'model_type': 'LogisticRegression', 'C': 0.00029208808341780947, 'lr_class_weight': 'balanced'}.
# [I 2026-04-26 05:51:16,057] Trial 27 finished with values: [0.7375048055049044, 0.7145005230125523, 0.7146158017588946] and parameters: {'model_type': 'LogisticRegression', 'C': 0.426361905360175, 'lr_class_weight': None}.
# [I 2026-04-26 05:51:16,078] Trial 28 finished with values: [0.7287543778590551, 0.7859524432157801, 0.7426909202367199] and parameters: {'model_type': 'LogisticRegression', 'C': 0.0006429002142212094, 'lr_class_weight': None}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:51:16] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:51:16,229] Trial 29 finished with values: [0.7334793501429013, 0.8341723326359832, 0.7991274205115945] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 51, 'xgb_max_depth': 4, 'learning_rate': 0.022870735579779394, 'scale_pos_weight': 2.3837903953853865}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:51:16] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:51:16,313] Trial 30 finished with values: [0.7313437661285678, 0.7815441945606695, 0.7965256195712807] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 109, 'xgb_max_depth': 5, 'learning_rate': 0.07065611041980592, 'scale_pos_weight': 2.2992657980944293}.
# [I 2026-04-26 05:51:16,337] Trial 31 finished with values: [0.7186390104715921, 0.7980844665271967, 0.7560830405771816] and parameters: {'model_type': 'LogisticRegression', 'C': 0.00029401794589686424, 'lr_class_weight': None}.
# [I 2026-04-26 05:51:17,401] Trial 32 finished with values: [0.7139152138464377, 0.7381434922295278, 0.7627908895857403] and parameters: {'model_type': 'RandomForest', 'n_estimators': 273, 'max_depth': 11, 'rf_class_weight': None}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:51:17] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:51:17,473] Trial 33 finished with values: [0.741021200653196, 0.7137580319784818, 0.7291160729021762] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 120, 'xgb_max_depth': 3, 'learning_rate': 0.03971121213163216, 'scale_pos_weight': 1.3542213588140979}.
# [I 2026-04-26 05:51:17,981] Trial 34 finished with values: [0.7357260339036453, 0.6583747384937239, 0.6837820951123477] and parameters: {'model_type': 'RandomForest', 'n_estimators': 142, 'max_depth': 3, 'rf_class_weight': 'balanced_subsample'}.
# [I 2026-04-26 05:51:18,010] Trial 35 finished with values: [0.7421510086563748, 0.7027747683801554, 0.6969855940395634] and parameters: {'model_type': 'LogisticRegression', 'C': 0.008423423635296962, 'lr_class_weight': None}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:51:18] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:51:18,325] Trial 36 finished with values: [0.7281495014619315, 0.9937238493723849, 0.9865168539325843] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 224, 'xgb_max_depth': 7, 'learning_rate': 0.0017406760671787808, 'scale_pos_weight': 2.2300144533983395}.
# [I 2026-04-26 05:51:18,367] Trial 37 finished with values: [0.737489521941906, 0.7255211446503287, 0.7316329898851768] and parameters: {'model_type': 'LogisticRegression', 'C': 2.4370551632385427, 'lr_class_weight': None}.
# [I 2026-04-26 05:51:18,407] Trial 38 finished with values: [0.7376470602066574, 0.7101249626419606, 0.7331655388678] and parameters: {'model_type': 'LogisticRegression', 'C': 1.1137963167994633, 'lr_class_weight': 'balanced'}.
# [I 2026-04-26 05:51:18,447] Trial 39 finished with values: [0.7377928418844868, 0.7101249626419606, 0.7331655388678] and parameters: {'model_type': 'LogisticRegression', 'C': 0.9805638874011487, 'lr_class_weight': 'balanced'}.
# [I 2026-04-26 05:51:18,852] Trial 40 finished with values: [0.7345691857505464, 0.7022937836222355, 0.7292162780279632] and parameters: {'model_type': 'RandomForest', 'n_estimators': 144, 'max_depth': 4, 'rf_class_weight': None}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:51:18] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:51:18,897] Trial 41 finished with values: [0.7397526649243404, 0.6891671025104602, 0.7365487289823891] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 57, 'xgb_max_depth': 3, 'learning_rate': 0.10906397771267527, 'scale_pos_weight': 1.7203812828225258}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:51:18] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:51:19,010] Trial 42 finished with values: [0.7248065159707355, 0.7932886282127913, 0.8020477212175512] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 104, 'xgb_max_depth': 7, 'learning_rate': 0.0016271066482215827, 'scale_pos_weight': 1.1033634423372154}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:51:19] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:51:19,361] Trial 43 finished with values: [0.7118019673472554, 0.7410527495517034, 0.7600725157383059] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 232, 'xgb_max_depth': 10, 'learning_rate': 0.01900809380697373, 'scale_pos_weight': 1.645912945882492}.
# [I 2026-04-26 05:51:19,384] Trial 44 finished with values: [0.7160149402706601, 0.7621180140466228, 0.7469466908730814] and parameters: {'model_type': 'LogisticRegression', 'C': 0.0002467640598008329, 'lr_class_weight': 'balanced'}.
# [I 2026-04-26 05:51:19,406] Trial 45 finished with values: [0.7302145459547349, 0.7534042513448894, 0.7347629264612265] and parameters: {'model_type': 'LogisticRegression', 'C': 0.0007353119099448623, 'lr_class_weight': 'balanced'}.
# [I 2026-04-26 05:51:19,912] Trial 46 finished with values: [0.7020234261751004, 0.7405157277346085, 0.7746858274585623] and parameters: {'model_type': 'RandomForest', 'n_estimators': 120, 'max_depth': 15, 'rf_class_weight': None}.
# [I 2026-04-26 05:51:19,955] Trial 47 finished with values: [0.7378645570647093, 0.7101249626419606, 0.7331655388678] and parameters: {'model_type': 'LogisticRegression', 'C': 0.6155035361040181, 'lr_class_weight': 'balanced'}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:51:19] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:51:20,202] Trial 48 finished with values: [0.7318099148000146, 0.8745096757322176, 0.8255398836560682] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 226, 'xgb_max_depth': 6, 'learning_rate': 0.0017472179340087973, 'scale_pos_weight': 1.9832317502336647}.
# [I 2026-04-26 05:51:20,236] Trial 49 finished with values: [0.7419770111699332, 0.6808269202032278, 0.6810588734586094] and parameters: {'model_type': 'LogisticRegression', 'C': 0.009829324480069712, 'lr_class_weight': 'balanced'}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:51:20] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:51:20,537] Trial 50 finished with values: [0.7150250356518498, 0.7776402794381351, 0.8078537240940278] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 176, 'xgb_max_depth': 9, 'learning_rate': 0.04282170893894739, 'scale_pos_weight': 1.3258688541628594}.
# [I 2026-04-26 05:51:21,520] Trial 51 finished with values: [0.7004956577046204, 0.7512001270173341, 0.7953860865407602] and parameters: {'model_type': 'RandomForest', 'n_estimators': 197, 'max_depth': 15, 'rf_class_weight': 'balanced_subsample'}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:51:21] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:51:21,678] Trial 52 finished with values: [0.7024784060889716, 0.7859477734608489, 0.8301464173720322] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 146, 'xgb_max_depth': 10, 'learning_rate': 0.1748490665654785, 'scale_pos_weight': 1.3915822695785929}.
# [I 2026-04-26 05:51:22,032] Trial 53 finished with values: [0.7133767621654223, 0.7564302525403468, 0.7881133143140076] and parameters: {'model_type': 'RandomForest', 'n_estimators': 73, 'max_depth': 11, 'rf_class_weight': 'balanced_subsample'}.
# [I 2026-04-26 05:51:22,332] Trial 54 finished with values: [0.7059313156678858, 0.7505043335325762, 0.787058213283663] and parameters: {'model_type': 'RandomForest', 'n_estimators': 79, 'max_depth': 12, 'rf_class_weight': 'balanced'}.
# [I 2026-04-26 05:51:22,371] Trial 55 finished with values: [0.7378727866755546, 0.7101249626419606, 0.7331655388678] and parameters: {'model_type': 'LogisticRegression', 'C': 0.5663354641950935, 'lr_class_weight': 'balanced'}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:51:22] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:51:22,633] Trial 56 finished with values: [0.7048085616168599, 0.7301021742378959, 0.7502589847796637] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 135, 'xgb_max_depth': 10, 'learning_rate': 0.13378039469082142, 'scale_pos_weight': 1.8579880547500367}.
# [I 2026-04-26 05:51:23,861] Trial 57 finished with values: [0.7275434494061159, 0.7285985131500299, 0.7641701836701011] and parameters: {'model_type': 'RandomForest', 'n_estimators': 276, 'max_depth': 9, 'rf_class_weight': 'balanced_subsample'}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:51:23] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:51:23,920] Trial 58 finished with values: [0.7258199337633893, 0.7764728407053199, 0.7562634472866363] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 72, 'xgb_max_depth': 5, 'learning_rate': 0.22564135127852009, 'scale_pos_weight': 2.901214293875112}.
# [I 2026-04-26 05:51:24,413] Trial 59 finished with values: [0.7379803594458886, 0.7272676329946204, 0.7619067267111499] and parameters: {'model_type': 'RandomForest', 'n_estimators': 123, 'max_depth': 7, 'rf_class_weight': 'balanced_subsample'}.
# [I 2026-04-26 05:51:24,432] Trial 60 finished with values: [0.7136071912690884, 0.8064526673640167, 0.7658677763893146] and parameters: {'model_type': 'LogisticRegression', 'C': 0.0001939964577577239, 'lr_class_weight': None}.
# [I 2026-04-26 05:51:24,453] Trial 61 finished with values: [0.725736461996245, 0.7899264046622834, 0.7464515596633108] and parameters: {'model_type': 'LogisticRegression', 'C': 0.0005187503589897554, 'lr_class_weight': None}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:51:24] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:51:24,646] Trial 62 finished with values: [0.7180106209006251, 0.7482628511655709, 0.7754521019498739] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 68, 'xgb_max_depth': 9, 'learning_rate': 0.05616265521770125, 'scale_pos_weight': 1.1626975612837995}.
# [I 2026-04-26 05:51:25,186] Trial 63 finished with values: [0.7041819355339312, 0.7461100941422594, 0.787058213283663] and parameters: {'model_type': 'RandomForest', 'n_estimators': 143, 'max_depth': 13, 'rf_class_weight': 'balanced'}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:51:25] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:51:25,312] Trial 64 finished with values: [0.7211960681270699, 0.7594235654512851, 0.7777155589088252] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 190, 'xgb_max_depth': 6, 'learning_rate': 0.17585297164588096, 'scale_pos_weight': 1.2223949646123027}.
# [I 2026-04-26 05:51:25,335] Trial 65 finished with values: [0.713597785999551, 0.8064526673640167, 0.7658677763893146] and parameters: {'model_type': 'LogisticRegression', 'C': 0.00019121254346210367, 'lr_class_weight': None}.
# [I 2026-04-26 05:51:26,214] Trial 66 finished with values: [0.7384523864107964, 0.7352902719665272, 0.7659738759342655] and parameters: {'model_type': 'RandomForest', 'n_estimators': 291, 'max_depth': 7, 'rf_class_weight': 'balanced'}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:51:26] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:51:26,334] Trial 67 finished with values: [0.7157692276039959, 0.8602669231918709, 0.8176627619730656] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 60, 'xgb_max_depth': 10, 'learning_rate': 0.02028521585798516, 'scale_pos_weight': 2.985929592238601}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:51:26] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:51:26,512] Trial 68 finished with values: [0.7167038762642739, 0.7817963613269576, 0.790668579169655] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 181, 'xgb_max_depth': 8, 'learning_rate': 0.05289977994339996, 'scale_pos_weight': 1.9090821295355465}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:51:26] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:51:26,569] Trial 69 finished with values: [0.7270955234443978, 0.7556177151823072, 0.7272969957765558] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 61, 'xgb_max_depth': 5, 'learning_rate': 0.2260916315842912, 'scale_pos_weight': 2.7805275677818324}.
# [I 2026-04-26 05:51:26,898] Trial 70 finished with values: [0.7277186225512499, 0.730064816198446, 0.7613113903755924] and parameters: {'model_type': 'RandomForest', 'n_estimators': 97, 'max_depth': 9, 'rf_class_weight': 'balanced'}.
# [I 2026-04-26 05:51:27,446] Trial 71 finished with values: [0.7382584027265876, 0.7108020771069935, 0.7323815811189965] and parameters: {'model_type': 'RandomForest', 'n_estimators': 184, 'max_depth': 7, 'rf_class_weight': None}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:51:27] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:51:27,678] Trial 72 finished with values: [0.7279790309515664, 0.7645509563658099, 0.7269264483225756] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 232, 'xgb_max_depth': 7, 'learning_rate': 0.010865224764765776, 'scale_pos_weight': 2.8654569667080265}.
# [I 2026-04-26 05:51:27,707] Trial 73 finished with values: [0.7423014929689732, 0.6974232292289301, 0.6908436092707424] and parameters: {'model_type': 'LogisticRegression', 'C': 0.007626351785803367, 'lr_class_weight': 'balanced'}.
# [I 2026-04-26 05:51:28,876] Trial 74 finished with values: [0.7059900986024945, 0.75362839958159, 0.7847770730672199] and parameters: {'model_type': 'RandomForest', 'n_estimators': 293, 'max_depth': 13, 'rf_class_weight': None}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:51:28] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:51:29,125] Trial 75 finished with values: [0.6910474766249659, 0.735626494321578, 0.7355606024384413] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 254, 'xgb_max_depth': 10, 'learning_rate': 0.2943000205007921, 'scale_pos_weight': 2.110863411205255}.
# [I 2026-04-26 05:51:29,468] Trial 76 finished with values: [0.7337632717170612, 0.7437331888822474, 0.7762183764411855] and parameters: {'model_type': 'RandomForest', 'n_estimators': 112, 'max_depth': 8, 'rf_class_weight': 'balanced'}.
# [I 2026-04-26 05:51:29,967] Trial 77 finished with values: [0.735249304303969, 0.6716928795576809, 0.6992844175134982] and parameters: {'model_type': 'RandomForest', 'n_estimators': 139, 'max_depth': 4, 'rf_class_weight': 'balanced_subsample'}.
# [I 2026-04-26 05:51:30,689] Trial 78 finished with values: [0.7035570729390409, 0.7369573744769874, 0.7746858274585623] and parameters: {'model_type': 'RandomForest', 'n_estimators': 190, 'max_depth': 14, 'rf_class_weight': None}.
# [I 2026-04-26 05:51:30,709] Trial 79 finished with values: [0.7357119259993392, 0.7719385086670651, 0.7324641029872916] and parameters: {'model_type': 'LogisticRegression', 'C': 0.0011609694921678087, 'lr_class_weight': None}.
# [I 2026-04-26 05:51:31,547] Trial 80 finished with values: [0.7014773327125855, 0.7479920053795577, 0.7918739537405984] and parameters: {'model_type': 'RandomForest', 'n_estimators': 159, 'max_depth': 14, 'rf_class_weight': 'balanced_subsample'}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:51:31] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:51:31,690] Trial 81 finished with values: [0.7255377756772676, 0.7666710251046025, 0.7849788827795043] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 288, 'xgb_max_depth': 4, 'learning_rate': 0.19736489170881125, 'scale_pos_weight': 1.9842325861590764}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:51:31] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:51:31,811] Trial 82 finished with values: [0.732164963725051, 0.7696970263000598, 0.7899523730931554] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 173, 'xgb_max_depth': 5, 'learning_rate': 0.03706898708058803, 'scale_pos_weight': 1.4802912375563861}.
# [I 2026-04-26 05:51:32,032] Trial 83 finished with values: [0.734262338831889, 0.7031296697549312, 0.7260509749369297] and parameters: {'model_type': 'RandomForest', 'n_estimators': 88, 'max_depth': 4, 'rf_class_weight': None}.
# [I 2026-04-26 05:51:32,052] Trial 84 finished with values: [0.7297454581365576, 0.7724942095038853, 0.7241765496427982] and parameters: {'model_type': 'LogisticRegression', 'C': 0.0007271087249685716, 'lr_class_weight': None}.
# [I 2026-04-26 05:51:32,271] Trial 85 finished with values: [0.7350382735687236, 0.7188200463239689, 0.7409579610025229] and parameters: {'model_type': 'RandomForest', 'n_estimators': 72, 'max_depth': 4, 'rf_class_weight': None}.
# [I 2026-04-26 05:51:33,441] Trial 86 finished with values: [0.7131827784812136, 0.7457598625224149, 0.7902235163746965] and parameters: {'model_type': 'RandomForest', 'n_estimators': 250, 'max_depth': 11, 'rf_class_weight': 'balanced_subsample'}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:51:33] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:51:33,582] Trial 87 finished with values: [0.7301093245017852, 0.7708831440526002, 0.757478683560443] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 237, 'xgb_max_depth': 4, 'learning_rate': 0.0033005298016110705, 'scale_pos_weight': 1.740944205582764}.
# [I 2026-04-26 05:51:34,389] Trial 88 finished with values: [0.7076771688257639, 0.7461100941422594, 0.7911253625067786] and parameters: {'model_type': 'RandomForest', 'n_estimators': 166, 'max_depth': 12, 'rf_class_weight': 'balanced_subsample'}.
# [I 2026-04-26 05:51:34,410] Trial 89 finished with values: [0.7206564407873621, 0.7643501569037656, 0.7499587390658524] and parameters: {'model_type': 'LogisticRegression', 'C': 0.00034344726058983886, 'lr_class_weight': 'balanced'}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:51:34] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:51:34,568] Trial 90 finished with values: [0.731305557221072, 1.0, 1.0] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 55, 'xgb_max_depth': 5, 'learning_rate': 0.003340275994330839, 'scale_pos_weight': 1.6549947043558293}.
# [I 2026-04-26 05:51:35,652] Trial 91 finished with values: [0.7027781990554759, 0.7536424088463838, 0.7948860019333694] and parameters: {'model_type': 'RandomForest', 'n_estimators': 220, 'max_depth': 13, 'rf_class_weight': 'balanced_subsample'}.
# [I 2026-04-26 05:51:35,887] Trial 92 finished with values: [0.7383824347186119, 0.7057260534967125, 0.7369261782943908] and parameters: {'model_type': 'RandomForest', 'n_estimators': 82, 'max_depth': 6, 'rf_class_weight': 'balanced'}.
# [I 2026-04-26 05:51:36,168] Trial 93 finished with values: [0.7356637239929602, 0.6723232964734012, 0.7004927734421049] and parameters: {'model_type': 'RandomForest', 'n_estimators': 109, 'max_depth': 4, 'rf_class_weight': 'balanced'}.
# [I 2026-04-26 05:51:37,177] Trial 94 finished with values: [0.7370615821779547, 0.684245180812911, 0.7199089901681088] and parameters: {'model_type': 'RandomForest', 'n_estimators': 275, 'max_depth': 4, 'rf_class_weight': 'balanced_subsample'}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:51:37] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:51:37,536] Trial 95 finished with values: [0.7235397437299184, 0.768020584279737, 0.8024426473015349] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 267, 'xgb_max_depth': 9, 'learning_rate': 0.004353680699148799, 'scale_pos_weight': 1.3417751747801316}.
# [I 2026-04-26 05:51:38,045] Trial 96 finished with values: [0.7394722703262571, 0.6974092199641363, 0.7132541909320256] and parameters: {'model_type': 'RandomForest', 'n_estimators': 193, 'max_depth': 6, 'rf_class_weight': None}.
# [I 2026-04-26 05:51:38,324] Trial 97 finished with values: [0.719349108321665, 0.7309754184100419, 0.7695989437200859] and parameters: {'model_type': 'RandomForest', 'n_estimators': 78, 'max_depth': 10, 'rf_class_weight': 'balanced'}.
# [I 2026-04-26 05:51:38,658] Trial 98 finished with values: [0.735506773557555, 0.6693206440526001, 0.7010881097776624] and parameters: {'model_type': 'RandomForest', 'n_estimators': 134, 'max_depth': 4, 'rf_class_weight': 'balanced'}.
# [I 2026-04-26 05:51:38,697] Trial 99 finished with values: [0.7374389686181425, 0.7133844515839809, 0.7146158017588946] and parameters: {'model_type': 'LogisticRegression', 'C': 0.6326147292744766, 'lr_class_weight': None}.
# Optimization finished!

# %%
# CELL 5: Pareto Front Visualization and Extraction
# Extract Pareto-optimal trials
pareto_trials = study.best_trials

print(f"Number of Pareto-optimal solutions found: {len(pareto_trials)}\n")

# Tabulate the Pareto front (Requirement for report)
pareto_data = []
for i, trial in enumerate(pareto_trials):
    pareto_data.append({
        "Trial ID": trial.number,
        "Model": trial.params.get("model_type"),
        "AUC": round(trial.values[0], 4),
        "Demo_Parity": round(trial.values[1], 4),
        "Equalized_Odds": round(trial.values[2], 4)
    })

pareto_df = pd.DataFrame(pareto_data)
print("--- Sample Pareto Optimal Solutions ---")
print(pareto_df.head(10).to_string(index=False))

# 3D Scatter Plot Visualization
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Extract all trial results for comparison
all_trials = [t for t in study.trials if t.values is not None]
all_auc = [t.values[0] for t in all_trials]
all_dp = [t.values[1] for t in all_trials]
all_eo = [t.values[2] for t in all_trials]

# Plot all points lightly
ax.scatter(all_auc, all_dp, all_eo, c='lightgray', label='All Configurations', alpha=0.5)

# Plot Pareto points boldly
pareto_auc = [t.values[0] for t in pareto_trials]
pareto_dp = [t.values[1] for t in pareto_trials]
pareto_eo = [t.values[2] for t in pareto_trials]

sc = ax.scatter(pareto_auc, pareto_dp, pareto_eo, c=pareto_auc, cmap='viridis', s=60, label='Pareto Front', edgecolor='k')

ax.set_xlabel('AUC-ROC (Accuracy)')
ax.set_ylabel('Demographic Parity')
ax.set_zlabel('Equalized Odds')
ax.set_title('3D Pareto Front: Accuracy vs Fairness Trade-offs')
plt.colorbar(sc, label='AUC-ROC Score', pad=0.1)
plt.legend()
plt.show()
# Out:
# Number of Pareto-optimal solutions found: 10
#
# --- Sample Pareto Optimal Solutions ---
#  Trial ID              Model    AUC  Demo_Parity  Equalized_Odds
#         9            XGBoost 0.7322       1.0000          1.0000
#        17       RandomForest 0.7345       0.7476          0.7780
#        19 LogisticRegression 0.7413       0.7084          0.6646
#        29            XGBoost 0.7335       0.8342          0.7991
#        33            XGBoost 0.7410       0.7138          0.7291
#        35 LogisticRegression 0.7422       0.7028          0.6970
#        41            XGBoost 0.7398       0.6892          0.7365
#        66       RandomForest 0.7385       0.7353          0.7660
#        73 LogisticRegression 0.7423       0.6974          0.6908
#        79 LogisticRegression 0.7357       0.7719          0.7325

# %%
# CELL 6: Quantitative Metrics (Hypervolume & Spacing Metric)
import numpy as np
from scipy.spatial.distance import pdist, squareform

# Extract the Pareto front objective values into a NumPy array
# shape: (N_pareto_points, 3)
pareto_values = np.array([t.values for t in pareto_trials])

# --- 1. Hypervolume Indicator ---
# We define a "Reference Point" representing the worst acceptable model.
# AUC worst ~ 0.5 (random guessing), DP worst ~ 0.0, EO worst ~ 0.0
ref_point = np.array([0.5, 0.0, 0.0])

# Ideal point representing theoretical perfection
ideal_point = np.array([1.0, 1.0, 1.0])

def monte_carlo_hypervolume(pareto_front, ref_point, ideal_point, n_samples=100000):
    """Calculates the hypervolume using Monte Carlo approximation."""
    # Generate random points within our performance bounding box
    random_points = np.random.uniform(low=ref_point, high=ideal_point, size=(n_samples, 3))
    
    # A point is 'dominated' (covered by our Pareto front) if any Pareto point 
    # is greater than or equal to it across all 3 objectives.
    dominated_counts = 0
    for pt in random_points:
        is_dominated = np.any(np.all(pareto_front >= pt, axis=1))
        if is_dominated:
            dominated_counts += 1
            
    box_volume = np.prod(ideal_point - ref_point)
    return (dominated_counts / n_samples) * box_volume

if len(pareto_values) > 0:
    hv = monte_carlo_hypervolume(pareto_values, ref_point, ideal_point)
    print(f"Hypervolume Indicator (Reference Point {ref_point}): {hv:.4f}")
else:
    print("No Pareto points available to calculate Hypervolume.")

# --- 2. Spacing Metric ---
# Measures how evenly distributed the Pareto points are (Lower is better/more even)
if len(pareto_values) > 2:
    # Calculate pairwise distances between all points in the Pareto front
    distances = pdist(pareto_values, metric='cityblock')
    dist_matrix = squareform(distances)
    
    # Ignore self-distances (diagonal)
    np.fill_diagonal(dist_matrix, np.inf)
    
    # Find distance to the nearest neighbor for each point
    d_i = np.min(dist_matrix, axis=1) 
    d_mean = np.mean(d_i)
    
    # Calculate spacing formula
    spacing_metric = np.sqrt(np.sum((d_i - d_mean)**2) / (len(pareto_values) - 1))
    print(f"Spacing Metric: {spacing_metric:.4f}")
else:
    print("Not enough Pareto points to calculate the spacing metric.")
# Out:
# Hypervolume Indicator (Reference Point [0.5 0.  0. ]): 0.2387
# Spacing Metric: 0.1076

# %%
# CELL 7: Extracting the "Knee" Point and Final Trade-off Visualization
import numpy as np
import matplotlib.pyplot as plt

print("="*50)
print(" APPENDIX A: SELECTED PARETO-OPTIMAL SOLUTION ")
print("="*50)

# 1. Find the "Accuracy-Maximized" Model (Baseline Proxy)
max_acc_trial = max(pareto_trials, key=lambda t: t.values[0])

# 2. Find our "Selected Compromise" Model (The Knee)
candidate_trials = [t for t in pareto_trials if t.values[0] > 0.65 and t.values[1] > 0.80]

if not candidate_trials:
    print("Strict knee criteria not met. Selecting the most balanced Pareto solution...")
    knee_trial = max(pareto_trials, key=lambda t: t.values[0] + t.values[1])
else:
    candidate_trials.sort(key=lambda x: x.values[1], reverse=True)
    knee_trial = candidate_trials[0]

# --- Print the Appendix Data ---
print(f"Selected Trial Number: {knee_trial.number}")
print("\n-- Objective Values (The 'Phenotype') --")
print(f"1. Maximize AUC-ROC:        {knee_trial.values[0]:.4f}")
print(f"2. Maximize Demo. Parity:   {knee_trial.values[1]:.4f}")
print(f"3. Maximize Equalized Odds: {knee_trial.values[2]:.4f}")

print("\n-- Decision Variables (The 'Genotype') --")
for key, value in knee_trial.params.items():
    if isinstance(value, float):
        print(f"{key}: {value:.6f}")
    else:
        print(f"{key}: {value}")

# --- FINAL VISUALIZATION: The Trade-off Bar Chart ---
# Prepare data for plotting
labels = ['AUC-ROC (Accuracy)', 'Demographic Parity', 'Equalized Odds']
max_acc_scores = [max_acc_trial.values[0], max_acc_trial.values[1], max_acc_trial.values[2]]
selected_scores = [knee_trial.values[0], knee_trial.values[1], knee_trial.values[2]]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=(10, 6))
rects1 = ax.bar(x - width/2, max_acc_scores, width, label='Max Accuracy Model', color='salmon', edgecolor='black')
rects2 = ax.bar(x + width/2, selected_scores, width, label='Selected MOO Model (Trial 93)', color='skyblue', edgecolor='black')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Scores (0.0 to 1.0)')
ax.set_title('The Cost of Fairness: Pure Accuracy vs. MOO Compromise')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.set_ylim(0, 1.15) # Leave room for labels
ax.legend(loc='upper left')

# Attach a text label above each bar, displaying its height
def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate(f'{height:.3f}',
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom', fontweight='bold')

autolabel(rects1)
autolabel(rects2)

fig.tight_layout()
plt.show()
# Out:
# ==================================================
#  APPENDIX A: SELECTED PARETO-OPTIMAL SOLUTION
# ==================================================
# Selected Trial Number: 9
#
# -- Objective Values (The 'Phenotype') --
# 1. Maximize AUC-ROC:        0.7322
# 2. Maximize Demo. Parity:   1.0000
# 3. Maximize Equalized Odds: 1.0000
#
# -- Decision Variables (The 'Genotype') --
# model_type: XGBoost
# xgb_n_estimators: 243
# xgb_max_depth: 4
# learning_rate: 0.001032
# scale_pos_weight: 2.630923

# %%
# CELL 8: Comparative Analysis - Running MOTPE Algorithm
import optuna

print("Starting Comparative MOO Loop using MOTPE Algorithm...")

# In modern Optuna, TPESampler automatically uses the MOTPE algorithm 
# under the hood when multiple directions are provided.
study_motpe = optuna.create_study(
    directions=["maximize", "maximize", "maximize"],
    sampler=optuna.samplers.TPESampler(seed=42)
)

# Run for the exact same number of trials to ensure a fair comparison
study_motpe.optimize(objective, n_trials=100, timeout=7000) 
print("MOTPE Optimization finished!\n")

pareto_trials_motpe = study_motpe.best_trials
print(f"Number of Pareto-optimal solutions found by MOTPE: {len(pareto_trials_motpe)}")
# Out:
# [I 2026-04-26 05:52:19,155] A new study created in memory with name: no-name-deab2ac0-e089-4246-a78c-2aa2105166de
# Starting Comparative MOO Loop using MOTPE Algorithm...
# [I 2026-04-26 05:52:19,905] Trial 0 finished with values: [0.7379004146548207, 0.6765027271368799, 0.7108728455897957] and parameters: {'model_type': 'RandomForest', 'n_estimators': 200, 'max_depth': 5, 'rf_class_weight': 'balanced_subsample'}.
# [I 2026-04-26 05:52:21,018] Trial 1 finished with values: [0.7059900986024945, 0.75362839958159, 0.7847770730672199] and parameters: {'model_type': 'RandomForest', 'n_estimators': 293, 'max_depth': 13, 'rf_class_weight': None}.
# [I 2026-04-26 05:52:21,585] Trial 2 finished with values: [0.719323243830437, 0.7468759339509863, 0.7843526748874166] and parameters: {'model_type': 'RandomForest', 'n_estimators': 123, 'max_depth': 10, 'rf_class_weight': 'balanced_subsample'}.
# [I 2026-04-26 05:52:22,197] Trial 3 finished with values: [0.7203672287490874, 0.7448539300657502, 0.7834508287553346] and parameters: {'model_type': 'RandomForest', 'n_estimators': 179, 'max_depth': 10, 'rf_class_weight': 'balanced'}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:52:22] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:52:22,366] Trial 4 finished with values: [0.7302874367936495, 1.0, 1.0] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 252, 'xgb_max_depth': 5, 'learning_rate': 0.0017456037635797405, 'scale_pos_weight': 2.3684660530243136}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:52:22] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:52:22,472] Trial 5 finished with values: [0.7157680519453036, 1.0, 1.0] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 58, 'xgb_max_depth': 10, 'learning_rate': 0.004375517173207359, 'scale_pos_weight': 2.325044568707964}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:52:22] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:52:22,608] Trial 6 finished with values: [0.7077923833775968, 0.8550601464435147, 0.8682723723005817] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 96, 'xgb_max_depth': 10, 'learning_rate': 0.08319514671870787, 'scale_pos_weight': 2.8789978831283785}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:52:22] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:52:22,665] Trial 7 finished with values: [0.7290059688191801, 1.0, 1.0] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 72, 'xgb_max_depth': 4, 'learning_rate': 0.001294295611551122, 'scale_pos_weight': 1.6506606615265287}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:52:22] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:52:22,772] Trial 8 finished with values: [0.7343281757186507, 0.746245517035266, 0.7712493810859877] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 139, 'xgb_max_depth': 5, 'learning_rate': 0.022096526145513846, 'scale_pos_weight': 1.2818484499495253}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:52:22] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:52:22,913] Trial 9 finished with values: [0.7321755446532807, 1.0, 1.0] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 243, 'xgb_max_depth': 4, 'learning_rate': 0.0010319982330247674, 'scale_pos_weight': 2.6309228569096685}.
# [I 2026-04-26 05:52:22,940] Trial 10 finished with values: [0.712204630449325, 0.7603715257023311, 0.7376040364982435] and parameters: {'model_type': 'LogisticRegression', 'C': 0.00010714845538373133, 'lr_class_weight': 'balanced'}.
# [I 2026-04-26 05:52:22,988] Trial 11 finished with values: [0.7375823989785877, 0.7255211446503287, 0.7316329898851768] and parameters: {'model_type': 'LogisticRegression', 'C': 7.149413485912379, 'lr_class_weight': None}.
# [I 2026-04-26 05:52:23,034] Trial 12 finished with values: [0.7375048055049042, 0.7255211446503287, 0.7316329898851768] and parameters: {'model_type': 'LogisticRegression', 'C': 6.181301326996549, 'lr_class_weight': None}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:52:23] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:52:23,244] Trial 13 finished with values: [0.7401970639099822, 0.7877829871488344, 0.7470077296995776] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 298, 'xgb_max_depth': 3, 'learning_rate': 0.01090193371486755, 'scale_pos_weight': 2.981676304319154}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:52:23] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:52:23,384] Trial 14 finished with values: [0.73999308712689, 0.8218255005977286, 0.784943023348474] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 260, 'xgb_max_depth': 3, 'learning_rate': 0.009312169670148755, 'scale_pos_weight': 2.868098575495565}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:52:23] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:52:23,557] Trial 15 finished with values: [0.7058208037508213, 0.757401561566049, 0.7531476611682206] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 213, 'xgb_max_depth': 7, 'learning_rate': 0.24805756679792476, 'scale_pos_weight': 2.3536361161912303}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:52:23] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:52:23,772] Trial 16 finished with values: [0.7269050667362655, 0.7844207635983264, 0.7631285361383376] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 191, 'xgb_max_depth': 7, 'learning_rate': 0.004540629761477583, 'scale_pos_weight': 1.9332922592369437}.
# [I 2026-04-26 05:52:23,803] Trial 17 finished with values: [0.742185102758448, 0.6721738643156007, 0.6679555796571806] and parameters: {'model_type': 'LogisticRegression', 'C': 0.0045094708298916, 'lr_class_weight': 'balanced'}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:52:23] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:52:24,022] Trial 18 finished with values: [0.724566681597532, 1.0, 1.0] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 252, 'xgb_max_depth': 3, 'learning_rate': 0.0011730624076708904, 'scale_pos_weight': 2.587188815375554}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:52:24] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:52:24,242] Trial 19 finished with values: [0.7285404079770794, 0.7482581814106395, 0.7721335439605781] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 298, 'xgb_max_depth': 6, 'learning_rate': 0.029679367592357366, 'scale_pos_weight': 1.0724753762397943}.
# [I 2026-04-26 05:52:24,474] Trial 20 finished with values: [0.7351958118334749, 0.6712072250448297, 0.6905547827317096] and parameters: {'model_type': 'RandomForest', 'n_estimators': 87, 'max_depth': 4, 'rf_class_weight': 'balanced'}.
# [I 2026-04-26 05:52:24,505] Trial 21 finished with values: [0.7411846172114082, 0.6981143529587568, 0.6973097870935798] and parameters: {'model_type': 'LogisticRegression', 'C': 0.0031792139471501094, 'lr_class_weight': 'balanced'}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:52:24] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:52:24,799] Trial 22 finished with values: [0.7244344199946625, 0.8219469142259415, 0.8107737668340106] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 154, 'xgb_max_depth': 8, 'learning_rate': 0.005111027515240094, 'scale_pos_weight': 2.020568251604009}.
# [I 2026-04-26 05:52:24,842] Trial 23 finished with values: [0.7384900074889458, 0.709704684698147, 0.7310553368071111] and parameters: {'model_type': 'LogisticRegression', 'C': 0.10424495003423194, 'lr_class_weight': 'balanced'}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:52:24] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:52:25,061] Trial 24 finished with values: [0.7306160333981121, 0.9910714285714286, 0.9893617021276596] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 241, 'xgb_max_depth': 4, 'learning_rate': 0.002888047449696413, 'scale_pos_weight': 2.6731967013252502}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:52:25] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:52:25,340] Trial 25 finished with values: [0.7232763961828714, 0.7685622758517633, 0.7616622838473185] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 218, 'xgb_max_depth': 8, 'learning_rate': 0.011648821855852205, 'scale_pos_weight': 2.006013419361244}.
# [I 2026-04-26 05:52:25,377] Trial 26 finished with values: [0.7392918067170084, 0.7135245442319187, 0.7156709027892392] and parameters: {'model_type': 'LogisticRegression', 'C': 0.06075644877584878, 'lr_class_weight': None}.
# [I 2026-04-26 05:52:26,580] Trial 27 finished with values: [0.7027111865100217, 0.7429580095636581, 0.787789121259991] and parameters: {'model_type': 'RandomForest', 'n_estimators': 299, 'max_depth': 15, 'rf_class_weight': None}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:52:26] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:52:26,685] Trial 28 finished with values: [0.730392070417253, 0.7583401823072324, 0.8038219413858958] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 117, 'xgb_max_depth': 5, 'learning_rate': 0.0694516022440212, 'scale_pos_weight': 1.6110693758122856}.
# [I 2026-04-26 05:52:26,881] Trial 29 finished with values: [0.7375747571970886, 0.7450547295277943, 0.7869049583854006] and parameters: {'model_type': 'RandomForest', 'n_estimators': 61, 'max_depth': 7, 'rf_class_weight': 'balanced'}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:52:26] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:52:27,017] Trial 30 finished with values: [0.7309881293741852, 1.0, 1.0] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 182, 'xgb_max_depth': 4, 'learning_rate': 0.0027637679281719584, 'scale_pos_weight': 2.684975926248518}.
# [I 2026-04-26 05:52:27,056] Trial 31 finished with values: [0.7127513117411858, 0.7651159967124925, 0.7487503831372457] and parameters: {'model_type': 'LogisticRegression', 'C': 0.00016473484803774423, 'lr_class_weight': 'balanced'}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:52:27] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:52:27,369] Trial 32 finished with values: [0.7308311789387799, 0.7284070531978482, 0.6909076420431907] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 272, 'xgb_max_depth': 6, 'learning_rate': 0.008744785509842801, 'scale_pos_weight': 2.497931997102444}.
# [I 2026-04-26 05:52:27,930] Trial 33 finished with values: [0.7345544900168941, 0.691898909145248, 0.7140027821658453] and parameters: {'model_type': 'RandomForest', 'n_estimators': 242, 'max_depth': 3, 'rf_class_weight': None}.
# [I 2026-04-26 05:52:28,588] Trial 34 finished with values: [0.7075760621782369, 0.7463202331141662, 0.7852545210194988] and parameters: {'model_type': 'RandomForest', 'n_estimators': 130, 'max_depth': 12, 'rf_class_weight': 'balanced_subsample'}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:52:28] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:52:28,708] Trial 35 finished with values: [0.7388139014586398, 0.7696176404662283, 0.7854131803330942] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 222, 'xgb_max_depth': 3, 'learning_rate': 0.039813490012757975, 'scale_pos_weight': 2.1600958065283304}.
# [I 2026-04-26 05:52:28,741] Trial 36 finished with values: [0.7406590977760065, 0.7073884862522415, 0.7040824747129417] and parameters: {'model_type': 'LogisticRegression', 'C': 0.0028100172774639083, 'lr_class_weight': 'balanced'}.
# [I 2026-04-26 05:52:29,436] Trial 37 finished with values: [0.7378598544299407, 0.7425424013747759, 0.7718447174215453] and parameters: {'model_type': 'RandomForest', 'n_estimators': 224, 'max_depth': 7, 'rf_class_weight': 'balanced'}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:52:29] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:52:29,661] Trial 38 finished with values: [0.7027264700730202, 0.7824781455469216, 0.8097378277153557] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 270, 'xgb_max_depth': 8, 'learning_rate': 0.18520897913450549, 'scale_pos_weight': 1.695953106089538}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:52:29] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:52:29,903] Trial 39 finished with values: [0.7187871434668058, 1.0, 1.0] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 158, 'xgb_max_depth': 9, 'learning_rate': 0.0024463275898589185, 'scale_pos_weight': 2.902897478290327}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:52:29] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:52:30,084] Trial 40 finished with values: [0.7316564913406861, 0.7481461072922893, 0.7761004880579068] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 193, 'xgb_max_depth': 6, 'learning_rate': 0.007053435754504345, 'scale_pos_weight': 1.4057523272255907}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:52:30] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:52:30,240] Trial 41 finished with values: [0.7396256937855857, 0.7934987671846981, 0.7651087736074588] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 292, 'xgb_max_depth': 3, 'learning_rate': 0.01743716408933591, 'scale_pos_weight': 2.9980683552160805}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:52:30] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:52:30,397] Trial 42 finished with values: [0.7381090940726817, 0.7422341975493126, 0.6906207665949479] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 231, 'xgb_max_depth': 4, 'learning_rate': 0.01198926380377154, 'scale_pos_weight': 2.746096922874284}.
# [I 2026-04-26 05:52:30,444] Trial 43 finished with values: [0.737739937243339, 0.7122683801554095, 0.7116037535661236] and parameters: {'model_type': 'LogisticRegression', 'C': 0.7359000641754879, 'lr_class_weight': None}.
# [I 2026-04-26 05:52:31,204] Trial 44 finished with values: [0.6999760165626797, 0.747086072922893, 0.7909721076085163] and parameters: {'model_type': 'RandomForest', 'n_estimators': 138, 'max_depth': 15, 'rf_class_weight': 'balanced_subsample'}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:52:31] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:52:31,408] Trial 45 finished with values: [0.7322966374985744, 0.841569224447101, 0.7979321061439159] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 269, 'xgb_max_depth': 5, 'learning_rate': 0.00178507565701371, 'scale_pos_weight': 1.8005532879599964}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:52:31] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:52:31,494] Trial 46 finished with values: [0.7381549447616763, 0.7623608413030484, 0.7766714479241374] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 123, 'xgb_max_depth': 3, 'learning_rate': 0.11560860947930533, 'scale_pos_weight': 2.155261552420784}.
# [I 2026-04-26 05:52:31,527] Trial 47 finished with values: [0.7407496234953037, 0.6884152719665272, 0.6769740409780021] and parameters: {'model_type': 'LogisticRegression', 'C': 0.002651898427607689, 'lr_class_weight': 'balanced'}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:52:31] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:52:31,906] Trial 48 finished with values: [0.72084454617811, 1.0, 1.0] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 209, 'xgb_max_depth': 9, 'learning_rate': 0.0010065034631758876, 'scale_pos_weight': 2.52472743449104}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:52:31] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:52:32,073] Trial 49 finished with values: [0.7206341032722108, 0.7799284593544531, 0.7872061518846123] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 170, 'xgb_max_depth': 7, 'learning_rate': 0.05574105022448812, 'scale_pos_weight': 2.1947591485176514}.
# [I 2026-04-26 05:52:32,856] Trial 50 finished with values: [0.734525686378936, 0.7204264420203228, 0.7441232640935562] and parameters: {'model_type': 'RandomForest', 'n_estimators': 256, 'max_depth': 8, 'rf_class_weight': None}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:52:32] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:52:33,035] Trial 51 finished with values: [0.7330760992114856, 0.7204964883442917, 0.7522575625397874] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 281, 'xgb_max_depth': 4, 'learning_rate': 0.003688400311300059, 'scale_pos_weight': 1.0324954152820487}.
# [I 2026-04-26 05:52:33,331] Trial 52 finished with values: [0.7379891768860799, 0.7063518006575016, 0.7277367788178153] and parameters: {'model_type': 'RandomForest', 'n_estimators': 96, 'max_depth': 6, 'rf_class_weight': 'balanced'}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:52:33] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:52:33,524] Trial 53 finished with values: [0.7306130942513818, 1.0, 1.0] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 255, 'xgb_max_depth': 5, 'learning_rate': 0.001664668726461443, 'scale_pos_weight': 2.4295112599130397}.
# [I 2026-04-26 05:52:33,558] Trial 54 finished with values: [0.7420934013804584, 0.6948922220561865, 0.6888512955933322] and parameters: {'model_type': 'LogisticRegression', 'C': 0.006345779687765046, 'lr_class_weight': None}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:52:33] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:52:33,830] Trial 55 finished with values: [0.7322437328574266, 0.7560099745965332, 0.7518487528886764] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 235, 'xgb_max_depth': 6, 'learning_rate': 0.002110278868468514, 'scale_pos_weight': 1.4906568222083005}.
# [I 2026-04-26 05:52:33,874] Trial 56 finished with values: [0.7377634504171824, 0.7122683801554095, 0.7116037535661236] and parameters: {'model_type': 'LogisticRegression', 'C': 0.6806232604433838, 'lr_class_weight': None}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:52:33] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:52:34,232] Trial 57 finished with values: [0.7214905706294593, 0.8165626867901973, 0.8093911865487289] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 195, 'xgb_max_depth': 9, 'learning_rate': 0.006700904715487085, 'scale_pos_weight': 2.2625469237400715}.
# [I 2026-04-26 05:52:34,441] Trial 58 finished with values: [0.706867139986856, 0.7283229976090855, 0.7620599816094122] and parameters: {'model_type': 'RandomForest', 'n_estimators': 50, 'max_depth': 12, 'rf_class_weight': 'balanced'}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:52:34] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:52:34,504] Trial 59 finished with values: [0.7294832862482027, 1.0, 1.0] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 55, 'xgb_max_depth': 3, 'learning_rate': 0.014788120513509343, 'scale_pos_weight': 2.8613945306503417}.
# [I 2026-04-26 05:52:34,539] Trial 60 finished with values: [0.7413680199673872, 0.6849269650328751, 0.6917277721453328] and parameters: {'model_type': 'LogisticRegression', 'C': 0.015344731272589448, 'lr_class_weight': None}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:52:34] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:52:34,701] Trial 61 finished with values: [0.730912887217886, 1.0, 1.0] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 86, 'xgb_max_depth': 5, 'learning_rate': 0.0016714182076416936, 'scale_pos_weight': 1.773693214668535}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:52:34] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:52:34,872] Trial 62 finished with values: [0.7295067994220461, 1.0, 1.0] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 262, 'xgb_max_depth': 4, 'learning_rate': 0.0014379133373443938, 'scale_pos_weight': 1.903450338944702}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:52:34] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:52:35,064] Trial 63 finished with values: [0.7155969936055924, 1.0, 1.0] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 105, 'xgb_max_depth': 10, 'learning_rate': 0.0010572942182121865, 'scale_pos_weight': 2.814167325003759}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:52:35] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:52:35,184] Trial 64 finished with values: [0.7296455271477227, 0.7439386580992229, 0.774703510716054] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 147, 'xgb_max_depth': 4, 'learning_rate': 0.0019475282677913926, 'scale_pos_weight': 1.234036145355752}.
# [I 2026-04-26 05:52:35,213] Trial 65 finished with values: [0.725581275048878, 0.7899264046622834, 0.7464515596633108] and parameters: {'model_type': 'LogisticRegression', 'C': 0.0005042186188493419, 'lr_class_weight': None}.
# [I 2026-04-26 05:52:35,442] Trial 66 finished with values: [0.7315471550823137, 0.7204964883442917, 0.735087119515243] and parameters: {'model_type': 'RandomForest', 'n_estimators': 56, 'max_depth': 8, 'rf_class_weight': None}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:52:35] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:52:35,526] Trial 67 finished with values: [0.7296249531206097, 1.0, 1.0] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 75, 'xgb_max_depth': 5, 'learning_rate': 0.0014458607731665982, 'scale_pos_weight': 2.991133439205052}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:52:35] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:52:35,632] Trial 68 finished with values: [0.7308411720376634, 1.0, 1.0] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 131, 'xgb_max_depth': 4, 'learning_rate': 0.0031280407958603706, 'scale_pos_weight': 2.3919065748696213}.
# [I 2026-04-26 05:52:35,680] Trial 69 finished with values: [0.7378445708669423, 0.7101249626419606, 0.7331655388678] and parameters: {'model_type': 'LogisticRegression', 'C': 0.46365256661532417, 'lr_class_weight': 'balanced'}.
# [I 2026-04-26 05:52:36,493] Trial 70 finished with values: [0.7197558862291571, 0.7384376867901972, 0.772610991912857] and parameters: {'model_type': 'RandomForest', 'n_estimators': 165, 'max_depth': 10, 'rf_class_weight': 'balanced_subsample'}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:52:36] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:52:36,635] Trial 71 finished with values: [0.7303814894890235, 1.0, 1.0] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 169, 'xgb_max_depth': 5, 'learning_rate': 0.0012493239111740165, 'scale_pos_weight': 2.5912602020837787}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:52:36] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:52:36,781] Trial 72 finished with values: [0.72951973166766, 0.7573128362223551, 0.8049964140568969] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 243, 'xgb_max_depth': 3, 'learning_rate': 0.29666633632618644, 'scale_pos_weight': 1.7759041432266205}.
# [I 2026-04-26 05:52:36,811] Trial 73 finished with values: [0.7354709159674435, 0.7041009787806336, 0.6829804541060523] and parameters: {'model_type': 'LogisticRegression', 'C': 0.0011583977658231929, 'lr_class_weight': 'balanced'}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:52:36] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:52:37,115] Trial 74 finished with values: [0.7277609462641682, 0.78747011356844, 0.8087098573591522] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 288, 'xgb_max_depth': 4, 'learning_rate': 0.13181604161584787, 'scale_pos_weight': 2.3246122902532287}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:52:37] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:52:37,433] Trial 75 finished with values: [0.717827218144646, 0.734678534070532, 0.7584827476292931] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 203, 'xgb_max_depth': 10, 'learning_rate': 0.0020975013008167386, 'scale_pos_weight': 1.2326279058158556}.
# [I 2026-04-26 05:52:37,830] Trial 76 finished with values: [0.7353721606373012, 0.6489605125523012, 0.6759543064626412] and parameters: {'model_type': 'RandomForest', 'n_estimators': 166, 'max_depth': 3, 'rf_class_weight': 'balanced'}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:52:37] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:52:38,037] Trial 77 finished with values: [0.7308929010201191, 0.7560940301852959, 0.743417802215316] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 228, 'xgb_max_depth': 6, 'learning_rate': 0.004173214157289646, 'scale_pos_weight': 1.8711627748742616}.
# [I 2026-04-26 05:52:38,078] Trial 78 finished with values: [0.7419617276069351, 0.684086409145248, 0.6834402188008394] and parameters: {'model_type': 'LogisticRegression', 'C': 0.011617216182038646, 'lr_class_weight': None}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:52:38] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:52:38,409] Trial 79 finished with values: [0.7281941764922342, 0.7479312985654513, 0.7237907402980317] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 249, 'xgb_max_depth': 7, 'learning_rate': 0.0056959879244600446, 'scale_pos_weight': 2.0894768879070855}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:52:38] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:52:38,558] Trial 80 finished with values: [0.7303426927521818, 1.0, 1.0] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 181, 'xgb_max_depth': 5, 'learning_rate': 0.0014104178845703581, 'scale_pos_weight': 2.659286548103188}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:52:38] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:52:38,708] Trial 81 finished with values: [0.7389732032114295, 0.7629305514046623, 0.7531078173559647] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 276, 'xgb_max_depth': 3, 'learning_rate': 0.028047007422160253, 'scale_pos_weight': 2.7646679333079778}.
# [I 2026-04-26 05:52:39,735] Trial 82 finished with values: [0.703355447473333, 0.7383536312014345, 0.782666871006531] and parameters: {'model_type': 'RandomForest', 'n_estimators': 265, 'max_depth': 14, 'rf_class_weight': None}.
# [I 2026-04-26 05:52:39,768] Trial 83 finished with values: [0.7407084754410778, 0.7085045576808129, 0.7070945229057128] and parameters: {'model_type': 'LogisticRegression', 'C': 0.0028537498635561468, 'lr_class_weight': 'balanced'}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:52:39] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:52:40,015] Trial 84 finished with values: [0.7305766488319243, 0.7398199342498506, 0.7724400537571028] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 205, 'xgb_max_depth': 5, 'learning_rate': 0.0031667124967202434, 'scale_pos_weight': 1.1244320166264603}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:52:40] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:52:40,165] Trial 85 finished with values: [0.7251762606294241, 0.8259302151823072, 0.7999920312375488] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 260, 'xgb_max_depth': 3, 'learning_rate': 0.001004471747762496, 'scale_pos_weight': 1.5361904910868915}.
# [I 2026-04-26 05:52:40,221] Trial 86 finished with values: [0.7376270740088904, 0.7101249626419606, 0.7331655388678] and parameters: {'model_type': 'LogisticRegression', 'C': 2.0161153948478097, 'lr_class_weight': 'balanced'}.
# [I 2026-04-26 05:52:41,092] Trial 87 finished with values: [0.7396074710758571, 0.71249252839211, 0.7399382264871619] and parameters: {'model_type': 'RandomForest', 'n_estimators': 210, 'max_depth': 6, 'rf_class_weight': 'balanced_subsample'}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:52:41] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:52:41,470] Trial 88 finished with values: [0.7241769507410764, 0.8527392782426778, 0.8061797752808989] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 300, 'xgb_max_depth': 8, 'learning_rate': 0.0021821755065561314, 'scale_pos_weight': 2.265224362556768}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:52:41] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:52:41,563] Trial 89 finished with values: [0.7305443182178896, 1.0, 1.0] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 102, 'xgb_max_depth': 4, 'learning_rate': 0.0013036135890640368, 'scale_pos_weight': 2.464255828196857}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:52:41] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:52:41,756] Trial 90 finished with values: [0.7278826269388081, 1.0, 1.0] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 161, 'xgb_max_depth': 7, 'learning_rate': 0.0024146859692695155, 'scale_pos_weight': 2.5815689047525052}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:52:41] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:52:41,911] Trial 91 finished with values: [0.7296843238845645, 1.0, 1.0] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 218, 'xgb_max_depth': 4, 'learning_rate': 0.0016945027525403968, 'scale_pos_weight': 2.0552244060171008}.
# [I 2026-04-26 05:52:41,955] Trial 92 finished with values: [0.737815179399638, 0.7134544979079498, 0.7146158017588946] and parameters: {'model_type': 'LogisticRegression', 'C': 0.16869053055584932, 'lr_class_weight': None}.
# [I 2026-04-26 05:52:42,324] Trial 93 finished with values: [0.7064380245642128, 0.7493882621040047, 0.781034116898121] and parameters: {'model_type': 'RandomForest', 'n_estimators': 82, 'max_depth': 12, 'rf_class_weight': 'balanced'}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:52:42] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:52:42,463] Trial 94 finished with values: [0.7387269027154189, 0.6983478407053199, 0.7294225826987009] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 225, 'xgb_max_depth': 3, 'learning_rate': 0.042077383035849195, 'scale_pos_weight': 1.3810207647421047}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:52:42] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:52:42,708] Trial 95 finished with values: [0.6985881514765684, 0.836367117453676, 0.8579846999760937] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 245, 'xgb_max_depth': 9, 'learning_rate': 0.17339340581362367, 'scale_pos_weight': 2.9275949893352644}.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [05:52:42] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-04-26 05:52:42,884] Trial 96 finished with values: [0.7274529236868187, 0.8192151075911537, 0.8419037373495896] and parameters: {'model_type': 'XGBoost', 'xgb_n_estimators': 267, 'xgb_max_depth': 5, 'learning_rate': 0.07797025290236115, 'scale_pos_weight': 2.72324047960477}.
# [I 2026-04-26 05:52:42,925] Trial 97 finished with values: [0.742009929613314, 0.6985393006575016, 0.6908436092707424] and parameters: {'model_type': 'LogisticRegression', 'C': 0.008122594767404909, 'lr_class_weight': 'balanced'}.
# [I 2026-04-26 05:52:42,973] Trial 98 finished with values: [0.7422015619801384, 0.6797108487746564, 0.6810588734586094] and parameters: {'model_type': 'LogisticRegression', 'C': 0.009192059936242697, 'lr_class_weight': 'balanced'}.
# [I 2026-04-26 05:52:44,247] Trial 99 finished with values: [0.7276186915624151, 0.7285985131500299, 0.7641701836701011] and parameters: {'model_type': 'RandomForest', 'n_estimators': 275, 'max_depth': 9, 'rf_class_weight': 'balanced_subsample'}.
# MOTPE Optimization finished!
#
# Number of Pareto-optimal solutions found by MOTPE: 12

# %%
# CELL 9: Quantitative Comparison (NSGA-II vs MOTPE)
# Extract values from the MOTPE Pareto front
pareto_values_motpe = np.array([t.values for t in pareto_trials_motpe])

print("--- ALGORITHM COMPARISON: HYPERVOLUME ---")
# hv was calculated in Cell 6 for NSGA-II
print(f"Hypervolume (NSGA-II): {hv:.4f}")

# Calculate Hypervolume for MOTPE
if len(pareto_values_motpe) > 0:
    hv_motpe = monte_carlo_hypervolume(pareto_values_motpe, ref_point, ideal_point)
    print(f"Hypervolume (MOTPE):   {hv_motpe:.4f}")
    
    if hv > hv_motpe:
        print("\nWinner: NSGA-II covers a larger Pareto trade-off space.")
    else:
        print("\nWinner: MOTPE covers a larger Pareto trade-off space.")
else:
    print("Not enough MOTPE points to calculate Hypervolume.")
# Out:
# --- ALGORITHM COMPARISON: HYPERVOLUME ---
# Hypervolume (NSGA-II): 0.2387
# Hypervolume (MOTPE):   0.2384
#
# Winner: NSGA-II covers a larger Pareto trade-off space.

# %%
# CELL 10: Visual Comparison of Pareto Fronts
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111, projection='3d')

# 1. Plot NSGA-II Front (Blue Circles)
pareto_auc_nsga = [t.values[0] for t in pareto_trials]
pareto_dp_nsga = [t.values[1] for t in pareto_trials]
pareto_eo_nsga = [t.values[2] for t in pareto_trials]

ax.scatter(pareto_auc_nsga, pareto_dp_nsga, pareto_eo_nsga, 
           c='blue', s=60, label='NSGA-II Front', marker='o', edgecolor='k', alpha=0.7)

# 2. Plot MOTPE Front (Red Triangles)
pareto_auc_motpe = [t.values[0] for t in pareto_trials_motpe]
pareto_dp_motpe = [t.values[1] for t in pareto_trials_motpe]
pareto_eo_motpe = [t.values[2] for t in pareto_trials_motpe]

ax.scatter(pareto_auc_motpe, pareto_dp_motpe, pareto_eo_motpe, 
           c='red', s=60, label='MOTPE Front', marker='^', edgecolor='k', alpha=0.7)

ax.set_xlabel('AUC-ROC (Accuracy)')
ax.set_ylabel('Demographic Parity')
ax.set_zlabel('Equalized Odds')
ax.set_title('Algorithm Comparison: NSGA-II vs. MOTPE Pareto Fronts')
ax.legend(loc='upper left')

plt.show()
